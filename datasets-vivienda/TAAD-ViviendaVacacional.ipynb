# %%
import pandas as pd

# %%
from google.colab import userdata
token=userdata.get('TAAD-GitHub')

# %%
# %%bash
# cd /content
# git clone https://github.com/alu0101430720/TAAD-Proyectos.git

# %%
# %%bash
# git config --global user.email "alu0101430720@ull.edu.es"
# git config --global user.name "Carlos Yanes"

# %%
# %%bash
# cd TAAD-Proyectos/
# mkdir -p datasets-vivienda

# %%
# %%bash
# cp -a "/content/drive/MyDrive/Máster Ciberseguridad e Inteligencia de Datos/TAAD/Vivienda Vacacional ESPAÑA/." /content/TAAD-Proyectos/datasets-vivienda/

# %%
# %%bash -s "$token"
# cd /content/TAAD-Proyectos/
# git add datasets-vivienda
# git commit -m "Añadir datasets-vivienda"
# git push https://$1@github.com/alu0101430720/TAAD-Proyectos.git
# Out:
# [main 441a2aa] Añadir datasets-vivienda
#  5 files changed, 2200539 deletions(-)
#  delete mode 100644 datasets-vivienda/TAAD-ViviendaVacacional.ipynb
#  delete mode 100644 datasets-vivienda/turismo_interno.csv
#  create mode 100644 datasets-vivienda/turismo_interno.zip
#  delete mode 100644 datasets-vivienda/turistas_CCAA_movil.csv
#  create mode 100644 datasets-vivienda/turistas_CCAA_movil.zip
# remote: warning: File datasets-vivienda/turistas_CCAA_movil.csv is 68.50 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: error: Trace: 0e97e3a02d5f97264ad0fb166a51d85fd9072e2a259846219818b730b687708d
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File datasets-vivienda/turismo_interno.csv is 120.29 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# ...

# %%
# %%bash
# cd /content/TAAD-Proyectos/
# git reset --hard HEAD~1
# Out:
# bash: line 1: cd: /content/TAAD-Proyectos/: No such file or directory
# fatal: not a git repository (or any of the parent directories): .git
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_1954/438361693.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd /content/TAAD-Proyectos/\ngit reset --hard HEAD~1\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     275     if line and not cell:
#     276       cell = ' '
# --> 277     return super().run_cell_magic(magic_name, line, cell)
#     278
#     279
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# ...

# %%
df = pd.read_csv('/content/TAAD-Proyectos/datasets-vivienda/turismo_interno.csv', sep=';')

# %%
df.isna().sum()
# Out:
# CCAA y provincia de origen            0
# CCAA y provincia de origen.1      16848
# CCAA y provincia de origen.2     336960
# CCAA y provincia de destino           0
# CCAA y provincia de destino.1     16848
# CCAA y provincia de destino.2    336960
# Concepto turístico                    0
# Periodo                               0
# Total                             30345
# dtype: int64
